# %% [markdown]
# #利用 Python 存取 API
# ###了解 Server Client 的架構與溝通方法
# ###知道 HTTP Request & Response 的內容
# ###什麼是 API？如何用 Python 程式存取 API 資料
#
# #作業目標
# ###比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# ###自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
# ###https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# ###http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
#
# ##比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get("https://api.github.com/events")
r.text
# Out:
# '[{"id":"11646079657","type":"CreateEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":244099548,"name":"direwolf-github/ephemeral-ci-9989e320","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-9989e320"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-01T06:32:46Z"},{"id":"11646079656","type":"ForkEvent","actor":{"id":12840994,"login":"saikalyan15","display_login":"saikalyan15","gravatar_id":"","url":"https://api.github.com/users/saikalyan15","avatar_url":"https://avatars.githubusercontent.com/u/12840994?"},"repo":{"id":68720867,"name":"firstcontributions/first-contributions","url":"https://api.github.com/repos/firstcontributions/first-contributions"},"payload":{"forkee":{"id":244099551,"node_id":"MDEwOlJlcG9zaXRvcnkyNDQwOTk1NTE=","name":"first-contributions","full_name":"saikalyan15/first-contributions","private":false,"owner":{"login":"saikalyan15","id":12840994,"node_id":"MDQ6VXNlcjEyODQwOTk0","avatar_url":"https://avatars1.githubusercontent.com/u/12840994?v=4","gravatar_id":"","url":"https://api.github.com/users/saikalyan15","html_url":"https://github.com/saikalyan15","followers_url":"https://api.github.com/users/saikalyan15/followers","following_url":"https://api.github.com/users/saikalyan15/following{/other_user}","gists_url":"https://api.github.com/users/saikalyan15/gists{/gist_id}","starred_url":"https://api.github.com/users/saikalyan15/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/saikalyan15/subscriptions","organizations_url":"https://api.github.com/users/saikalyan15/orgs","repos_url":"https://api.github.com/users/saikalyan15/repos","events_url":"https://api.github.com/users/saikalyan15/events{/privacy}","received_events_url":"https://api.github.com/users/saikalyan15/received_events","type":"User","site_admin":false},"html_url":"https://github.com/saikalyan15/first-contributions","description":"🚀✨ Help beginners to contribute to open source projects","fork":true,"url":"https://api.github.com/repos/saikalyan15/first-contributions","forks_url":"https://api.github.com/repos/saikalyan15/first-contributions/forks","keys_url":"https://api.github.com/repos/saikalyan15/first-contributions/keys{/key_id}","collaborators_url":"https://api.github.com/repos/saikalyan15/first-contributions/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/saikalyan15/first-contributions/teams","hooks_url":"https://api.github.com/repos/saikalyan15/first-contributions/hooks","issue_events_url":"https://api.github.com/repos/saikalyan15/first-contributions/issues/events{/number}","events_url":"https://api.github.com/repos/saikalyan15/first-contributions/events","assignees_url":"https://api.github.com/repos/saikalyan15/first-contributions/assignees{/user}","branches_url":"https://api.github.com/repos/saikalyan15/first-contributions/branches{/branch}","tags_url":"https://api.github.com/repos/saikalyan15/first-contributions/tags","blobs_url":"https://api.github.com/repos/saikalyan15/first-contributions/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/saikalyan15/first-contributions/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/saikalyan15/first-contributions/git/refs{/sha}","trees_url":"https://api.github.com/repos/saikalyan15/first-contributions/git/trees{/sha}","statuses_url":"https://api.github.com/repos/saikalyan15/first-contributions/statuses/{sha}","languages_url":"https://api.github.com/repos/saikalyan15/first-contributions/languages","stargazers_url":"https://api.github.com/repos/saikalyan15/first-contributions/stargazers","contributors_url":"https://api.github.com/repos/saikalyan15/first-contributions/contributors","subscribers_url":"https://api.github.com/repos/saikalya ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11646079657',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 244099548,
#    'name': 'direwolf-github/ephemeral-ci-9989e320',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-9989e320'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079656',
#   'type': 'ForkEvent',
#   'actor': {'id': 12840994,
#    'login': 'saikalyan15',
#    'display_login': 'saikalyan15',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saikalyan15',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12840994?'},
#   'repo': {'id': 68720867,
#    'name': 'firstcontributions/first-contributions',
#    'url': 'https://api.github.com/repos/firstcontributions/first-contributions'},
#   'payload': {'forkee': {'id': 244099551,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQwOTk1NTE=',
#     'name': 'first-contributions',
#     'full_name': 'saikalyan15/first-contributions',
#     'private': False,
#     'owner': {'login': 'saikalyan15',
#      'id': 12840994,
#      'node_id': 'MDQ6VXNlcjEyODQwOTk0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/12840994?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/saikalyan15',
#      'html_url': 'https://github.com/saikalyan15',
#      'followers_url': 'https://api.github.com/users/saikalyan15/followers',
#      'following_url': 'https://api.github.com/users/saikalyan15/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/saikalyan15/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/saikalyan15/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/saikalyan15/subscriptions',
#      'organizations_url': 'https://api.github.com/users/saikalyan15/orgs',
#      'repos_url': 'https://api.github.com/users/saikalyan15/repos',
#      'events_url': 'https://api.github.com/users/saikalyan15/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/saikalyan15/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/saikalyan15/first-contributions',
#     'description': '🚀✨ Help beginners to contribute to open source projects',
#     'fork': True,
#     'url': 'https://api.github.com/repos/saikalyan15/first-contributions',
#     'forks_url': 'https://api.github.com/repos/saikalyan15/first-contributions/forks',
#     'keys_url': 'https://api.github.com/repos/saikalyan15/first-contributions/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/saikalyan15/first-contributions/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/saikalyan15/first-contributions/teams',
#     'hooks_url': 'https://api.github.com/repos/saikalyan15/first-contributions/hooks',
#     'issue_events_url': 'https://api.github.com/repos/saikalyan15/first-contributions/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/saikalyan15/first-contributions/events',
#     'assignees_url': 'https://api.github.com/repos/saikalyan15/first-contributions/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/saikalyan15/first-contributions/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/saikalyan15/first-contributions/tags',
#     'blobs_url': 'https://api.github.com/repos/saikalyan15/first-contributions/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/saikalyan15/first-contributions/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/saikalyan15/first-contributions/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/saikalyan15/first-contributions/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/saikalyan15/first-contributions/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/saikalyan15/first-contributions/languages',
#     'stargazers_url': 'https://api.github.com/repos/saikalyan15/first-contributions/stargazers',
#     'contributors_url': 'https://api.github.com/repos/saikalyan15/first-contributions/contributors',
#     'subscribers_url': 'https://api.github.com/repos/saikalyan15/first-contributions/subscribers',
#     'subscription_url': 'https://api.github.com/repos/saikalyan15/first-contributions/subscription',
#     'commits_url': 'https://api.github.com/repos/saikalyan15/first-contributions/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/saikalyan15/first-contributions/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/saikalyan15/first-contributions/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/saikalyan15/first-contributions/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/saikalyan15/first-contributions/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/saikalyan15/first-contributions/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/saikalyan15/first-contributions/merges',
#     'archive_url': 'https://api.github.com/repos/saikalyan15/first-contributions/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/saikalyan15/first-contributions/downloads',
#     'issues_url': 'https://api.github.com/repos/saikalyan15/first-contributions/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/saikalyan15/first-contributions/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/saikalyan15/first-contributions/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/saikalyan15/first-contributions/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/saikalyan15/first-contributions/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/saikalyan15/first-contributions/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/saikalyan15/first-contributions/deployments',
#     'created_at': '2020-03-01T06:32:45Z',
#     'updated_at': '2020-03-01T06:27:36Z',
#     'pushed_at': '2020-03-01T06:27:18Z',
#     'git_url': 'git://github.com/saikalyan15/first-contributions.git',
#     'ssh_url': 'git@github.com:saikalyan15/first-contributions.git',
#     'clone_url': 'https://github.com/saikalyan15/first-contributions.git',
#     'svn_url': 'https://github.com/saikalyan15/first-contributions',
#     'homepage': 'https://firstcontributions.github.io',
#     'size': 235423,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z',
#   'org': {'id': 37713493,
#    'login': 'firstcontributions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/firstcontributions',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37713493?'}},
#  {'id': '11646079654',
#   'type': 'CreateEvent',
#   'actor': {'id': 47803195,
#    'login': 'Allegorii',
#    'display_login': 'Allegorii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Allegorii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47803195?'},
#   'repo': {'id': 244099552,
#    'name': 'Allegorii/5.4.22',
#    'url': 'https://api.github.com/repos/Allegorii/5.4.22'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079652',
#   'type': 'PushEvent',
#   'actor': {'id': 35210249,
#    'login': 'thunderHzx',
#    'display_login': 'thunderHzx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thunderHzx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35210249?'},
#   'repo': {'id': 243700109,
#    'name': 'thunderHzx/blog',
#    'url': 'https://api.github.com/repos/thunderHzx/blog'},
#   'payload': {'push_id': 4701197191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5fa460eb99597cb0007e2993aac2fd11ff2874e0',
#    'before': 'aa0ae46f0a75c1ef339d91248ebaa236aa06e8ec',
#    'commits': [{'sha': '5fa460eb99597cb0007e2993aac2fd11ff2874e0',
#      'author': {'email': '16847559056@163.com', 'name': 'hzx'},
#      'message': '更新回滚测试',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thunderHzx/blog/commits/5fa460eb99597cb0007e2993aac2fd11ff2874e0'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079642',
#   'type': 'CreateEvent',
#   'actor': {'id': 51390418,
#    'login': 'sqnguyen829',
#    'display_login': 'sqnguyen829',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sqnguyen829',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51390418?'},
#   'repo': {'id': 184679548,
#    'name': 'learn-co-students/displaying-associations-rails-online-test-2018',
#    'url': 'https://api.github.com/repos/learn-co-students/displaying-associations-rails-online-test-2018'},
#   'payload': {'ref': 'dependabot/bundler/nokogiri-1.10.8',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z',
#   'org': {'id': 8825476,
#    'login': 'learn-co-students',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/learn-co-students',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8825476?'}},
#  {'id': '11646079650',
#   'type': 'CreateEvent',
#   'actor': {'id': 61104304,
#    'login': 'MULTIMEDIA1720',
#    'display_login': 'MULTIMEDIA1720',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MULTIMEDIA1720',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61104304?'},
#   'repo': {'id': 244099129,
#    'name': 'MULTIMEDIA1720/multimedia1720.github.io',
#    'url': 'https://api.github.com/repos/MULTIMEDIA1720/multimedia1720.github.io'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Website Profil Kelas Multimedia',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079640',
#   'type': 'PushEvent',
#   'actor': {'id': 52064201,
#    'login': 'pratannaimjoi',
#    'display_login': 'pratannaimjoi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pratannaimjoi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52064201?'},
#   'repo': {'id': 216297104,
#    'name': 'pratannaimjoi/tanflex.github',
#    'url': 'https://api.github.com/repos/pratannaimjoi/tanflex.github'},
#   'payload': {'push_id': 4701197186,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '23e8f3983372eeb87381535e13353170077a7438',
#    'before': '7405143b87c42a3c917df4a97b76ffa4f4334b30',
#    'commits': [{'sha': '23e8f3983372eeb87381535e13353170077a7438',
#      'author': {'email': '52064201+pratannaimjoi@users.noreply.github.com',
#       'name': 'Pratan naimjoi'},
#      'message': 'Update flexmax.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pratannaimjoi/tanflex.github/commits/23e8f3983372eeb87381535e13353170077a7438'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079648',
#   'type': 'GollumEvent',
#   'actor': {'id': 23412689,
#    'login': 'aryam7',
#    'display_login': 'aryam7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aryam7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23412689?'},
#   'repo': {'id': 75028068,
#    'name': 'aryam7/studycloud',
#    'url': 'https://api.github.com/repos/aryam7/studycloud'},
#   'payload': {'pages': [{'page_name': 'Routes',
#      'title': 'Routes',
#      'summary': None,
#      'action': 'edited',
#      'sha': 'd1de7a2cfcff3cad767d75e88dd36c68a75e303f',
#      'html_url': 'https://github.com/aryam7/studycloud/wiki/Routes'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079635',
#   'type': 'PushEvent',
#   'actor': {'id': 156685,
#    'login': 'MarkEWaite',
#    'display_login': 'MarkEWaite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarkEWaite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156685?'},
#   'repo': {'id': 51146391,
#    'name': 'MarkEWaite/jenkins-bugs',
#    'url': 'https://api.github.com/repos/MarkEWaite/jenkins-bugs'},
#   'payload': {'push_id': 4701197182,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/JENKINS-33202-x/branch-2',
#    'head': '45ca6ad6beb1fe358de785282e73c48b8751df31',
#    'before': '6e1c087a9991e12c6d41660003c48fb37c3bf7a0',
#    'commits': [{'sha': '45ca6ad6beb1fe358de785282e73c48b8751df31',
#      'author': {'email': 'mwaite@mark-pc2.markwaite.net',
#       'name': 'Jenkins Docker User'},
#      'message': 'Added date stamp 2020-03-01 00:32:41 on branch-2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MarkEWaite/jenkins-bugs/commits/45ca6ad6beb1fe358de785282e73c48b8751df31'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079639',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594396,
#    'name': 'Lombiq/Associativy-Notions-Demo-Instance',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Notions-Demo-Instance'},
#   'payload': {'push_id': 4701197185,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-63',
#    'head': '013438946d4a3b9555c5b1979cfef0acf13ac855',
#    'before': '013438946d4a3b9555c5b1979cfef0acf13ac855',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11646079638',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 244099530,
#    'name': 'direwolf-github/ephemeral-ci-1c054428',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1',
#     'id': 382005882,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyMDA1ODgy',
#     'html_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428/pull/1',
#     'diff_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428/pull/1.diff',
#     'patch_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Direwolf review apps test branch-6b8a46d4',
#     'user': {'login': 'direwolf-github',
#      'id': 10810283,
#      'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/10810283?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/direwolf-github',
#      'html_url': 'https://github.com/direwolf-github',
#      'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#      'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#      'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#      'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#      'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Direwolf review apps test branch-6b8a46d4',
#     'created_at': '2020-03-01T06:32:46Z',
#     'updated_at': '2020-03-01T06:32:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/statuses/072f4cf876ca24b973b5d66418509abdae2cd844',
#     'head': {'label': 'direwolf-github:branch-6b8a46d4',
#      'ref': 'branch-6b8a46d4',
#      'sha': '072f4cf876ca24b973b5d66418509abdae2cd844',
#      'user': {'login': 'direwolf-github',
#       'id': 10810283,
#       'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/10810283?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/direwolf-github',
#       'html_url': 'https://github.com/direwolf-github',
#       'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#       'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#       'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#       'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#       'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 244099530,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQwOTk1MzA=',
#       'name': 'ephemeral-ci-1c054428',
#       'full_name': 'direwolf-github/ephemeral-ci-1c054428',
#       'private': False,
#       'owner': {'login': 'direwolf-github',
#        'id': 10810283,
#        'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/10810283?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/direwolf-github',
#        'html_url': 'https://github.com/direwolf-github',
#        'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#        'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#        'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#        'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#        'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428',
#       'forks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/forks',
#       'keys_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/teams',
#       'hooks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/hooks',
#       'issue_events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/events',
#       'assignees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/tags',
#       'blobs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/languages',
#       'stargazers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/stargazers',
#       'contributors_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/contributors',
#       'subscribers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/subscribers',
#       'subscription_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/subscription',
#       'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/merges',
#       'archive_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/downloads',
#       'issues_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/deployments',
#       'created_at': '2020-03-01T06:32:35Z',
#       'updated_at': '2020-03-01T06:32:39Z',
#       'pushed_at': '2020-03-01T06:32:45Z',
#       'git_url': 'git://github.com/direwolf-github/ephemeral-ci-1c054428.git',
#       'ssh_url': 'git@github.com:direwolf-github/ephemeral-ci-1c054428.git',
#       'clone_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428.git',
#       'svn_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'direwolf-github:master',
#      'ref': 'master',
#      'sha': '23338deff7a1035e83851f200d75c8852372c3f3',
#      'user': {'login': 'direwolf-github',
#       'id': 10810283,
#       'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/10810283?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/direwolf-github',
#       'html_url': 'https://github.com/direwolf-github',
#       'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#       'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#       'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#       'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#       'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 244099530,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQwOTk1MzA=',
#       'name': 'ephemeral-ci-1c054428',
#       'full_name': 'direwolf-github/ephemeral-ci-1c054428',
#       'private': False,
#       'owner': {'login': 'direwolf-github',
#        'id': 10810283,
#        'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/10810283?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/direwolf-github',
#        'html_url': 'https://github.com/direwolf-github',
#        'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#        'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#        'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#        'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#        'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428',
#       'forks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/forks',
#       'keys_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/teams',
#       'hooks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/hooks',
#       'issue_events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/events',
#       'assignees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/tags',
#       'blobs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/languages',
#       'stargazers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/stargazers',
#       'contributors_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/contributors',
#       'subscribers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/subscribers',
#       'subscription_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/subscription',
#       'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/merges',
#       'archive_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/downloads',
#       'issues_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/deployments',
#       'created_at': '2020-03-01T06:32:35Z',
#       'updated_at': '2020-03-01T06:32:39Z',
#       'pushed_at': '2020-03-01T06:32:45Z',
#       'git_url': 'git://github.com/direwolf-github/ephemeral-ci-1c054428.git',
#       'ssh_url': 'git@github.com:direwolf-github/ephemeral-ci-1c054428.git',
#       'clone_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428.git',
#       'svn_url': 'https://github.com/direwolf-github/ephemeral-ci-1c054428',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1'},
#      'html': {'href': 'https://github.com/direwolf-github/ephemeral-ci-1c054428/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/statuses/072f4cf876ca24b973b5d66418509abdae2cd844'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079632',
#   'type': 'IssuesEvent',
#   'actor': {'id': 5655108,
#    'login': 'andrewtelnov',
#    'display_login': 'andrewtelnov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andrewtelnov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5655108?'},
#   'repo': {'id': 48416896,
#    'name': 'surveyjs/survey-creator',
#    'url': 'https://api.github.com/repos/surveyjs/survey-creator'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/surveyjs/survey-creator/issues/674',
#     'repository_url': 'https://api.github.com/repos/surveyjs/survey-creator',
#     'labels_url': 'https://api.github.com/repos/surveyjs/survey-creator/issues/674/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/surveyjs/survey-creator/issues/674/comments',
#     'events_url': 'https://api.github.com/repos/surveyjs/survey-creator/issues/674/events',
#     'html_url': 'https://github.com/surveyjs/survey-creator/issues/674',
#     'id': 569477326,
#     'node_id': 'MDU6SXNzdWU1Njk0NzczMjY=',
#     'number': 674,
#     'title': "Can't update survey attributes in modal mode",
#     'user': {'login': 'mgralikowski',
#      'id': 17027876,
#      'node_id': 'MDQ6VXNlcjE3MDI3ODc2',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/17027876?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mgralikowski',
#      'html_url': 'https://github.com/mgralikowski',
#      'followers_url': 'https://api.github.com/users/mgralikowski/followers',
#      'following_url': 'https://api.github.com/users/mgralikowski/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mgralikowski/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mgralikowski/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mgralikowski/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mgralikowski/orgs',
#      'repos_url': 'https://api.github.com/users/mgralikowski/repos',
#      'events_url': 'https://api.github.com/users/mgralikowski/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mgralikowski/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 302571351,
#       'node_id': 'MDU6TGFiZWwzMDI1NzEzNTE=',
#       'url': 'https://api.github.com/repos/surveyjs/survey-creator/labels/bug',
#       'name': 'bug',
#       'color': 'fc2929',
#       'default': True,
#       'description': None},
#      {'id': 577952893,
#       'node_id': 'MDU6TGFiZWw1Nzc5NTI4OTM=',
#       'url': 'https://api.github.com/repos/surveyjs/survey-creator/labels/fixed',
#       'name': 'fixed',
#       'color': 'd93f0b',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/surveyjs/survey-creator/milestones/6',
#      'html_url': 'https://github.com/surveyjs/survey-creator/milestone/6',
#      'labels_url': 'https://api.github.com/repos/surveyjs/survey-creator/milestones/6/labels',
#      'id': 5121235,
#      'node_id': 'MDk6TWlsZXN0b25lNTEyMTIzNQ==',
#      'number': 6,
#      'title': 'v1.5.11',
#      'description': None,
#      'creator': {'login': 'andrewtelnov',
#       'id': 5655108,
#       'node_id': 'MDQ6VXNlcjU2NTUxMDg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/5655108?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/andrewtelnov',
#       'html_url': 'https://github.com/andrewtelnov',
#       'followers_url': 'https://api.github.com/users/andrewtelnov/followers',
#       'following_url': 'https://api.github.com/users/andrewtelnov/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/andrewtelnov/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/andrewtelnov/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/andrewtelnov/subscriptions',
#       'organizations_url': 'https://api.github.com/users/andrewtelnov/orgs',
#       'repos_url': 'https://api.github.com/users/andrewtelnov/repos',
#       'events_url': 'https://api.github.com/users/andrewtelnov/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/andrewtelnov/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 4,
#      'closed_issues': 2,
#      'state': 'closed',
#      'created_at': '2020-02-19T12:50:29Z',
#      'updated_at': '2020-03-01T06:32:45Z',
#      'due_on': None,
#      'closed_at': '2020-02-28T17:26:05Z'},
#     'comments': 3,
#     'created_at': '2020-02-23T10:58:45Z',
#     'updated_at': '2020-03-01T06:32:45Z',
#     'closed_at': '2020-03-01T06:32:45Z',
#     'author_association': 'NONE',
#     'body': 'There is fatal error on modify any survey attribute but only in "modal mode". I prefer modal than tab so it\'s critical for me.\r\n\r\n`  Cannot set property pages of #<SurveyModel> which has only a getter`\r\n\r\nInstruction:\r\n\r\n1. Go to: https://surveyjs.io/Examples/Survey-Creator/?id=options&theme=bootstrap\r\n2. Change mode to "Show toolbox in right container and hide property grid".\r\n3. Open settings modal.\r\n3. Change any survey attribute and click "Apply".\r\n\r\n* browser: any.\r\n* editor version: 1.5.10\r\n'}},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z',
#   'org': {'id': 25198306,
#    'login': 'surveyjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/surveyjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25198306?'}},
#  {'id': '11646079627',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 450800,
#    'login': 'sthagen',
#    'display_login': 'sthagen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sthagen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/450800?'},
#   'repo': {'id': 211110460,
#    'name': 'sthagen/go',
#    'url': 'https://api.github.com/repos/sthagen/go'},
#   'payload': {'action': 'opened',
#    'number': 183,
#    'pull_request': {'url': 'https://api.github.com/repos/sthagen/go/pulls/183',
#     'id': 382005881,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyMDA1ODgx',
#     'html_url': 'https://github.com/sthagen/go/pull/183',
#     'diff_url': 'https://github.com/sthagen/go/pull/183.diff',
#     'patch_url': 'https://github.com/sthagen/go/pull/183.patch',
#     'issue_url': 'https://api.github.com/repos/sthagen/go/issues/183',
#     'number': 183,
#     'state': 'open',
#     'locked': False,
#     'title': 'Sync Fork from Upstream Repo ',
#     'user': {'login': 'sthagen',
#      'id': 450800,
#      'node_id': 'MDQ6VXNlcjQ1MDgwMA==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/450800?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sthagen',
#      'html_url': 'https://github.com/sthagen',
#      'followers_url': 'https://api.github.com/users/sthagen/followers',
#      'following_url': 'https://api.github.com/users/sthagen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sthagen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sthagen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sthagen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sthagen/orgs',
#      'repos_url': 'https://api.github.com/users/sthagen/repos',
#      'events_url': 'https://api.github.com/users/sthagen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sthagen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This PR will be imported into Gerrit with the title and first\r\ncomment (this text) used to generate the subject and body of\r\nthe Gerrit change.\r\n\r\n**Please ensure you adhere to every item in this list.**\r\n\r\nMore info can be found at https://github.com/golang/go/wiki/CommitMessage\r\n\r\n+ The PR title is formatted as follows: `net/http: frob the quux before blarfing`\r\n  + The package name goes before the colon\r\n  + The part after the colon uses the verb tense + phrase that completes the blank in,\r\n    "This change modifies Go to ___________"\r\n  + Lowercase verb after the colon\r\n  + No trailing period\r\n  + Keep the title as short as possible. ideally under 76 characters or shorter\r\n+ No Markdown\r\n+ The first PR comment (this one) is wrapped at 76 characters, unless it\'s\r\n  really needed (ASCII art, table, or long link)\r\n+ If there is a corresponding issue, add either `Fixes #1234` or `Updates #1234`\r\n  (the latter if this is not a complete fix) to this comment\r\n+ If referring to a repo other than `golang/go` you can use the\r\n  `owner/repo#issue_number` syntax: `Fixes golang/tools#1234`\r\n+ We do not use Signed-off-by lines in Go. Please don\'t add them.\r\n  Our Gerrit server & GitHub bots enforce CLA compliance instead.\r\n+ Delete these instructions once you have read and applied them\r\n',
#     'created_at': '2020-03-01T06:32:45Z',
#     'updated_at': '2020-03-01T06:32:45Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/sthagen/go/pulls/183/commits',
#     'review_comments_url': 'https://api.github.com/repos/sthagen/go/pulls/183/comments',
#     'review_comment_url': 'https://api.github.com/repos/sthagen/go/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/sthagen/go/issues/183/comments',
#     'statuses_url': 'https://api.github.com/repos/sthagen/go/statuses/1e9665da8fd8e2e095eb0e99a3b83118f600dc0b',
#     'head': {'label': 'golang:master',
#      'ref': 'master',
#      'sha': '1e9665da8fd8e2e095eb0e99a3b83118f600dc0b',
#      'user': {'login': 'golang',
#       'id': 4314092,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQzMTQwOTI=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/4314092?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/golang',
#       'html_url': 'https://github.com/golang',
#       'followers_url': 'https://api.github.com/users/golang/followers',
#       'following_url': 'https://api.github.com/users/golang/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/golang/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/golang/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/golang/subscriptions',
#       'organizations_url': 'https://api.github.com/users/golang/orgs',
#       'repos_url': 'https://api.github.com/users/golang/repos',
#       'events_url': 'https://api.github.com/users/golang/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/golang/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 23096959,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzA5Njk1OQ==',
#       'name': 'go',
#       'full_name': 'golang/go',
#       'private': False,
#       'owner': {'login': 'golang',
#        'id': 4314092,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQzMTQwOTI=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/4314092?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/golang',
#        'html_url': 'https://github.com/golang',
#        'followers_url': 'https://api.github.com/users/golang/followers',
#        'following_url': 'https://api.github.com/users/golang/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/golang/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/golang/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/golang/subscriptions',
#        'organizations_url': 'https://api.github.com/users/golang/orgs',
#        'repos_url': 'https://api.github.com/users/golang/repos',
#        'events_url': 'https://api.github.com/users/golang/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/golang/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/golang/go',
#       'description': 'The Go programming language',
#       'fork': False,
#       'url': 'https://api.github.com/repos/golang/go',
#       'forks_url': 'https://api.github.com/repos/golang/go/forks',
#       'keys_url': 'https://api.github.com/repos/golang/go/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/golang/go/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/golang/go/teams',
#       'hooks_url': 'https://api.github.com/repos/golang/go/hooks',
#       'issue_events_url': 'https://api.github.com/repos/golang/go/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/golang/go/events',
#       'assignees_url': 'https://api.github.com/repos/golang/go/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/golang/go/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/golang/go/tags',
#       'blobs_url': 'https://api.github.com/repos/golang/go/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/golang/go/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/golang/go/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/golang/go/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/golang/go/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/golang/go/languages',
#       'stargazers_url': 'https://api.github.com/repos/golang/go/stargazers',
# ...
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 244099530,
#    'name': 'direwolf-github/ephemeral-ci-1c054428',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428'},
#   'payload': {'push_id': 4701197177,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch-6b8a46d4',
#    'head': '072f4cf876ca24b973b5d66418509abdae2cd844',
#    'before': '23338deff7a1035e83851f200d75c8852372c3f3',
#    'commits': [{'sha': '072f4cf876ca24b973b5d66418509abdae2cd844',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'add readme.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428/commits/072f4cf876ca24b973b5d66418509abdae2cd844'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079623',
#   'type': 'PushEvent',
#   'actor': {'id': 38429025,
#    'login': 'chuan12',
#    'display_login': 'chuan12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chuan12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38429025?'},
#   'repo': {'id': 129750934,
#    'name': 'chuan12/shenzhouzd',
#    'url': 'https://api.github.com/repos/chuan12/shenzhouzd'},
#   'payload': {'push_id': 4701197175,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7a2eb2c1fd5252f19ed5d8e7ce95bb99043bca5a',
#    'before': '06519c8706ee09e4cd1d403104ba07764f605411',
#    'commits': [{'sha': '7a2eb2c1fd5252f19ed5d8e7ce95bb99043bca5a',
#      'author': {'email': '38429025+chuan12@users.noreply.github.com',
#       'name': 'chuan12'},
#      'message': 'Update data.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chuan12/shenzhouzd/commits/7a2eb2c1fd5252f19ed5d8e7ce95bb99043bca5a'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079625',
#   'type': 'CreateEvent',
#   'actor': {'id': 16633397,
#    'login': 'ksetrad',
#    'display_login': 'ksetrad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ksetrad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16633397?'},
#   'repo': {'id': 243085293,
#    'name': 'ksetrad/nurgler',
#    'url': 'https://api.github.com/repos/ksetrad/nurgler'},
#   'payload': {'ref': 'core',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079621',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197736026,
#    'name': 'adeo-gitlab/sync-github-gitlab-48',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-48'},
#   'payload': {'ref': '2020-03-01_06-32-36_809_scenario2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11646079620',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 244099508,
#    'name': 'direwolf-github/ephemeral-ci-1ae97607',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1ae97607'},
#   'payload': {'ref': 'branch-1229574b',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079619',
#   'type': 'PushEvent',
#   'actor': {'id': 17038786,
#    'login': 'peter0530',
#    'display_login': 'peter0530',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peter0530',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17038786?'},
#   'repo': {'id': 239459953,
#    'name': 'peter0530/maskdata-backup',
#    'url': 'https://api.github.com/repos/peter0530/maskdata-backup'},
#   'payload': {'push_id': 4701197174,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2551358bce00134d819e68b12c8f75d141dbb126',
#    'before': '47b7379c734a7f4068ce9103a1b36252db1f8f14',
#    'commits': [{'sha': '2551358bce00134d819e68b12c8f75d141dbb126',
#      'author': {'email': 'a1515twtw@gmail.com', 'name': 'peter0530'},
#      'message': 'update 2020-03-01 14:32:39',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peter0530/maskdata-backup/commits/2551358bce00134d819e68b12c8f75d141dbb126'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:46Z'},
#  {'id': '11646079616',
#   'type': 'PushEvent',
#   'actor': {'id': 26441151,
#    'login': 'propredator23',
#    'display_login': 'propredator23',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/propredator23',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26441151?'},
#   'repo': {'id': 242855517,
#    'name': 'propredator23/CPI211_Team9',
#    'url': 'https://api.github.com/repos/propredator23/CPI211_Team9'},
#   'payload': {'push_id': 4701197172,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Map',
#    'head': '80ef2ce80f168d312b085d0319d8a3eb896628d8',
#    'before': '11730ed6051801da4baf756bee7cd3fa566c4201',
#    'commits': [{'sha': '80ef2ce80f168d312b085d0319d8a3eb896628d8',
#      'author': {'email': 'christiandash@hotmail.com', 'name': 'propredator23'},
#      'message': 'Navmesh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/propredator23/CPI211_Team9/commits/80ef2ce80f168d312b085d0319d8a3eb896628d8'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079611',
#   'type': 'PushEvent',
#   'actor': {'id': 61645141,
#    'login': 'zqandzq',
#    'display_login': 'zqandzq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zqandzq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61645141?'},
#   'repo': {'id': 244098939,
#    'name': 'zqandzq/wangzhenqin',
#    'url': 'https://api.github.com/repos/zqandzq/wangzhenqin'},
#   'payload': {'push_id': 4701197168,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7667209d4d7fb13a75cbb5162345e0d73ab6f1dd',
#    'before': '494e54c013e19c8401ce598e1bfa09f6a3bbd6f2',
#    'commits': [{'sha': '7667209d4d7fb13a75cbb5162345e0d73ab6f1dd',
#      'author': {'email': '61645141+zqandzq@users.noreply.github.com',
#       'name': 'zqandzq'},
#      'message': 'Update index.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zqandzq/wangzhenqin/commits/7667209d4d7fb13a75cbb5162345e0d73ab6f1dd'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079613',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197736038,
#    'name': 'adeo-gitlab/sync-github-gitlab-49',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-49'},
#   'payload': {'ref': '2020-03-01_06-32-34_224_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11646079605',
#   'type': 'PushEvent',
#   'actor': {'id': 54208851,
#    'login': '07gamer',
#    'display_login': '07gamer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/07gamer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54208851?'},
#   'repo': {'id': 240859636,
#    'name': '07gamer/HTML-CSS-JavaScript',
#    'url': 'https://api.github.com/repos/07gamer/HTML-CSS-JavaScript'},
#   'payload': {'push_id': 4701197163,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c8a491d95cf530236cb946369df65872092a863a',
#    'before': '9aaeb7bce5af40eb465f3a04681a918289e5560e',
#    'commits': [{'sha': 'c8a491d95cf530236cb946369df65872092a863a',
#      'author': {'email': '1139406816@qq.com', 'name': 'zhengwenhao'},
#      'message': 'HTML+CSS+JavaScript 学习笔记',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/07gamer/HTML-CSS-JavaScript/commits/c8a491d95cf530236cb946369df65872092a863a'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079601',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 244099530,
#    'name': 'direwolf-github/ephemeral-ci-1c054428',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1c054428'},
#   'payload': {'ref': 'branch-6b8a46d4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079599',
#   'type': 'PushEvent',
#   'actor': {'id': 27520658,
#    'login': 'manohar-rajawat',
#    'display_login': 'manohar-rajawat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/manohar-rajawat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27520658?'},
#   'repo': {'id': 244098657,
#    'name': 'manohar-rajawat/gitDemo',
#    'url': 'https://api.github.com/repos/manohar-rajawat/gitDemo'},
#   'payload': {'push_id': 4701197159,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '339c1a80c0e536c0f6961c07c53264dd2433ba59',
#    'before': '5eebc53df29e5c5563fff75d5205a13e7ddb7692',
#    'commits': [{'sha': 'd13da5508c7bb6d5280843883176edbdcb5045b0',
#      'author': {'email': 'manoharsingh1920@gmail.com',
#       'name': 'manohar singh rajawat'},
#      'message': 'Removing Readme.md file for testin purpose',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/manohar-rajawat/gitDemo/commits/d13da5508c7bb6d5280843883176edbdcb5045b0'},
#     {'sha': '339c1a80c0e536c0f6961c07c53264dd2433ba59',
#      'author': {'email': 'manoharsingh1920@gmail.com',
#       'name': 'manohar singh rajawat'},
#      'message': "Merge branch 'master' of github.com:manohar-rajawat/gitDemo",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/manohar-rajawat/gitDemo/commits/339c1a80c0e536c0f6961c07c53264dd2433ba59'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079597',
#   'type': 'CreateEvent',
#   'actor': {'id': 6579365,
#    'login': 'grahamcba',
#    'display_login': 'grahamcba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/grahamcba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6579365?'},
#   'repo': {'id': 25497997,
#    'name': 'grahamcba/Python',
#    'url': 'https://api.github.com/repos/grahamcba/Python'},
#   'payload': {'ref': 'MelbourneReddit',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Repository dumping ground for small Python projects.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079591',
#   'type': 'PushEvent',
#   'actor': {'id': 51390418,
#    'login': 'sqnguyen829',
#    'display_login': 'sqnguyen829',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sqnguyen829',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51390418?'},
#   'repo': {'id': 215127399,
#    'name': 'learn-co-students/displaying-associations-rails-austin-web-091619',
#    'url': 'https://api.github.com/repos/learn-co-students/displaying-associations-rails-austin-web-091619'},
#   'payload': {'push_id': 4701197144,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '0758eb2351738ac9f1139fad5fa1ad1f9cb8f769',
#    'before': 'd3d5c64e3124bd27ba0a1d73c27e74036a6b0b98',
#    'commits': [{'sha': '0758eb2351738ac9f1139fad5fa1ad1f9cb8f769',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump rack from 2.0.6 to 2.0.8\n\nBumps [rack](https://github.com/rack/rack) from 2.0.6 to 2.0.8.\n- [Release notes](https://github.com/rack/rack/releases)\n- [Changelog](https://github.com/rack/rack/blob/master/CHANGELOG.md)\n- [Commits](https://github.com/rack/rack/compare/2.0.6...2.0.8)\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/learn-co-students/displaying-associations-rails-austin-web-091619/commits/0758eb2351738ac9f1139fad5fa1ad1f9cb8f769'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z',
#   'org': {'id': 8825476,
#    'login': 'learn-co-students',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/learn-co-students',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8825476?'}},
#  {'id': '11646079596',
#   'type': 'CreateEvent',
#   'actor': {'id': 21698520,
#    'login': 'RahmadaniBayuAji',
#    'display_login': 'RahmadaniBayuAji',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RahmadaniBayuAji',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21698520?'},
#   'repo': {'id': 111677218,
#    'name': 'RahmadaniBayuAji/anon_voter',
#    'url': 'https://api.github.com/repos/RahmadaniBayuAji/anon_voter'},
#   'payload': {'ref': 'snyk-fix-6bee6064a3f8c4dbc9a6919b6b64f5c1',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'Anonymous Vote Machine',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079593',
#   'type': 'PushEvent',
#   'actor': {'id': 46189249,
#    'login': 'Walkers15',
#    'display_login': 'Walkers15',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Walkers15',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46189249?'},
#   'repo': {'id': 243713819,
#    'name': 'Walkers15/Messenger',
#    'url': 'https://api.github.com/repos/Walkers15/Messenger'},
#   'payload': {'push_id': 4701197152,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ac4a10eb932c29433861d42ea61fa1cebfdc1048',
#    'before': 'c967a96492a8122b14cb03589a0378dbf8aa2c0a',
#    'commits': [{'sha': 'ac4a10eb932c29433861d42ea61fa1cebfdc1048',
#      'author': {'email': '46189249+Walkers15@users.noreply.github.com',
#       'name': '백승훈'},
#      'message': 'Added Flowchart_friend.drawio',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Walkers15/Messenger/commits/ac4a10eb932c29433861d42ea61fa1cebfdc1048'}]},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'},
#  {'id': '11646079592',
#   'type': 'PushEvent',
#   'actor': {'id': 10506187,
#    'login': 'wessilfie',
#    'display_login': 'wessilfie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wessilfie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10506187?'},
#   'repo': {'id': 116565279,
#    'name': 'wessilfie/wessilfie.github.io',
#    'url': 'https://api.github.com/repos/wessilfie/wessilfie.github.io'},
#   'payload': {'push_id': 4701197149,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '6d439180e3fdc3a695929e7496887e933575e00f',
#    'before': 'da2635e1c26f870d44ec6641ebc86d47a5ad12b5',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-01T06:32:45Z'}]

# %%
print("1. Get API response directly, type:{0}", type(r.text))
print("2. Get API response and parsing, type:{0}", type(json.loads(r.text)))
# Out:
# 1. Get API response directly, type:{0} <class 'str'>
# 2. Get API response and parsing, type:{0} <class 'list'>

# %% [markdown]
# ##Ans: 直接取得API回傳的資料型態為"字串"(string); 透過json.loads函式處理後取得之資料型態為"列表"(List)

# %% [markdown]
# ##自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
# ###https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# ###http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
api = "http://odata.wra.gov.tw/v4/RealtimeWaterLevel"
resp = requests.get(api)
resp.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H029","WaterLevel": 145.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H070","WaterLevel": 226.25},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H021","WaterLevel": 1.28},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H017","WaterLevel": 25.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2560H019","WaterLevel": 4.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H001","WaterLevel": 224.21},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H075","WaterLevel": 92.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.2},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H066","WaterLevel": 138.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H077","WaterLevel": 740.49},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1550H014","WaterLevel": 26.75},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1670H004","WaterLevel": 2.98},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H019","WaterLevel": 109.97},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H012","WaterLevel": 0.7},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H061","WaterLevel": 266.23},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H072","WaterLevel": 248.86},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H039","WaterLevel": 38.99},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H012","WaterLevel": 0.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.61},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H009","WaterLevel": 0.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H037","WaterLevel": 32.01},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H015","WaterLevel": 0.05},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H018","WaterLevel": 124.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H009","WaterLevel": 4.85},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H043","WaterLevel": 23.04},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H043","WaterLevel": 79.32},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H033","WaterLevel": 23.4},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H010","WaterLevel": 0.19},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.57},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H032","WaterLevel": 0.13},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.62},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1680H005","WaterLevel": 0.11},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H026","WaterLevel": 106.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1350H031","WaterLevel": -0.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H040","WaterLevel": 1.76},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H018","WaterLevel": 10.01},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H027","WaterLevel": 26.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM", ...

# %%
json.loads(resp.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.75},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.98},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.7},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.23},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.85},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.04},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.32},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.4},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.19},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.57},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.62},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': 106.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.45},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.54},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.03},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.97},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.27},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.07},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 13.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': 145.89},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.16},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.06},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.94},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.46},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.67},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.23},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.82},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.6},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.79},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.39},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 97.9},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.74},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 622.43},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.68},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.81},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.12},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.09},
#   {'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
